# %% [markdown]
# # Loading and Processing of Carpediem Email Data

# %% [markdown]
# To begin, we need load and create an appropriate dataset in order to proceed with visualization and data exploration. We will begin by adapting the email scrapper using pop from the Olin Snapshot Project. Unfortunately, the data schema of embedded JSON is much too deep and complicated for usage by pandas (an attempt was made to convert into pandas), thus we will try to load and save the data into a csv file of our design for easy pandas conversion.
#
# To finish we will need to do the following to the data:
#     1. Manually tag all of them
#     2. Split the data into training and test data appropriately
#         a. Will require sorting to ensure enough of different tags make it into both
#     3. Create a key file for the test
#     4. Remove the tags from the test file

# %% [markdown]
# The goal is to first create a list of dictionaries with the email title, subject line, and msg content. In addition we want to store these emails in dictionary form into a csv with the appropriate headers (
# *Note that poplib only loads fresh emails, marking unread doesn't work. Have to resend/forward emails to create initial file

# %%
import os
import sys
import time
import poplib
import email
import csv
from io import StringIO
from datetime import datetime

def list_to_dict(msg):
    d = dict()
    for field in msg:
        if "*" in field:
            field = "".join(field.split("*"))
        if ":" not in field:
            continue

        print(field)
        key, value = field.split(": ", 1)
        if key == "Sent":
            key = "date"
            value = value.split(" (", 1)[0]
            # ex. string at this point: Tuesday, April 3, 2018 3:51:10 PM
            #value = datetime.strptime(value, "%A, %B %e, %Y %T %p")
        if key == "From":
            key = "who"
            value = field.split("Behalf Of", 1)[1]
        if key == "Subject":
            key = "name"
        if key == "To":
            continue
        d[key] = value
    return d

def get_mail():
    """ fetches new messages from a gmail account using POP, then parses it
    into a dictionary for PostGresDB
    """

    """
    Connect to gmail accound and retrieve messages
    """
    pop_conn = poplib.POP3_SSL('pop.gmail.com')
    pop_conn.user('olinsnapshot@gmail.com')
    pop_conn.pass_('hackingthelibrary')
    # messages = [pop_conn.retr(i) for i in range(1, len(pop_conn.list()[1]) + 1)]

    messages = []

    # Parse messages
    resp, items, octets = pop_conn.list()

    for item in items:
        id, size = item.decode().split(' ')
        resp, text, octets = pop_conn.retr(id)

        text = [x.decode() for x in text]
        text = "\n".join(text)
        file = StringIO(text)

        orig_email = email.message_from_file(file).as_string()
        messages.append(orig_email.split("\n"))

    pop_conn.quit()

    msg_dicts = []
    for msg in messages:
        if not msg: continue
        header_index = -1
        msg_info = []
        body = []
        i = 0
        while(len(msg) > i):
            line = msg[i]
            if "CarpediemOn Behalf Of" in line:
                header_index = i
                msg_info = msg[i:i+5]
                i = i + 5
            elif header_index != -1:
                if line == "":
                    i = i + 1
                    continue
                elif "--" in line:
                    break
                else:
                    body.append(line)

            i = i + 1
        msg_info.append("body: " + " ".join(body))
        print(msg_info)
        current_dict = list_to_dict(msg_info)
        categories = []
        print(list(current_dict.keys()))
        msg_dicts.append(current_dict)

    print(msg_dicts)
    return msg_dicts

def create_data_csv(data_list,location):
    '''
    Converts a data list of dictionaries into a csv file at argument location
    '''
    test_data_1 = open(location, 'w')

    csvwriter = csv.writer(test_data_1)
    count = 0
    for email in data_list:
        if count == 0:
            header = email.keys()
            csvwriter.writerow(header)
            count +=1
        csvwriter.writerow(email.values())

    test_data_1.close()

# %% [markdown]
# Loading Data: *in reality done in 4 parts b/c of tedious reforwarding and manually combined

# %%
emails_data = get_mail()
#don't run this or it will overwrite 
#create_data_csv(emails_data,'./data/test_data.csv')
# Out:
# ['From: CarpediemOn Behalf OfGrace Montagnino', 'Sent: Thursday, May 10, 2018 12:48:36 PM (UTC-05:00) Eastern Time (US & Can=', 'ada)', 'To: Carpediem@lists.olin.edu', 'Subject: [Carpediem] Donate to the Needham Community Council', "body: From: CarpeSERV [mailto:carpeserv-bounces@lists.olin.edu] On Behalf Of Just= in Kunimune (Forwarding) Sent: Wednesday, May 9, 2018 9:41 PM To: carpediem@lists olin. edu <carpediem@lists.olin.edu>; carpeserv@lists.o= lin.edu Subject: [CarpeSERV] More boxes for the Needham Community Council tl;dr =96 put any excess food and cleaning items in the labelled bins in th= e residence halls to donate them to a food bank. Long version: If you saw Melissa's email, it's the same thing, but now with more boxes th= at will be there for longer! There is now a labelled box in the WH anteloun= ge, and will be one in EH tomorrow, for donating food and toiletries to the=  Needham Community Council Food Pantry. These boxes will be out through the=  end of the semester, so feel free to wait until the last moment to put thi= ngs in. A full list of what kinds of things for which the NCC is looking ca= n be found here<http://needhamcommunitycouncil.org/wp-content/uploads/2018/= 05/FP-Wishlist-May-2018.pdf>. Thank you, Justin Director of SERV"]
# From: CarpediemOn Behalf OfGrace Montagnino
# Sent: Thursday, May 10, 2018 12:48:36 PM (UTC-05:00) Eastern Time (US & Can=
# To: Carpediem@lists.olin.edu
# Subject: [Carpediem] Donate to the Needham Community Council
# body: From: CarpeSERV [mailto:carpeserv-bounces@lists.olin.edu] On Behalf Of Just= in Kunimune (Forwarding) Sent: Wednesday, May 9, 2018 9:41 PM To: carpediem@lists olin. edu <carpediem@lists.olin.edu>; carpeserv@lists.o= lin.edu Subject: [CarpeSERV] More boxes for the Needham Community Council tl;dr =96 put any excess food and cleaning items in the labelled bins in th= e residence halls to donate them to a food bank. Long version: If you saw Melissa's email, it's the same thing, but now with more boxes th= at will be there for longer! There is now a labelled box in the WH anteloun= ge, and will be one in EH tomorrow, for donating food and toiletries to the=  Needham Community Council Food Pantry. These boxes will be out through the=  end of the semester, so feel free to wait until the last moment to put thi= ngs in. A full list of what kinds of things for which the NCC is looking ca= n be found here<http://needhamcommunitycouncil.org/wp-content/uploads/2018/= 05/FP-Wishlist-May-2018.pdf>. Thank you, Justin Director of SERV
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfJared Briskman', 'Sent: Thursday, May 10, 2018 12:51:53 PM (UTC-05:00) Eastern Time (US & Can=', 'ada)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] ORO Show Tomorrow!', "body: tl;dr Olin Rock Orchestra is performing tomorrow, Friday the 11th, at 5pm i= n the Library Hey y'all! ORO is playing a short set in the upper level of the library tomorrow! Come and listen to some jammin' music, and send finals out with a bang. We're Oliners, we're an ensemble that could be called an orchestra, and we = might even play some Rock! (When we aren't playing jazz, movie scores or whatever genre Lucky Chops is= ) See you there! Event Link: http://events.olin.build/view/5af33baff199d40019cbe9ff"]
# From: CarpediemOn Behalf OfJared Briskman
# Sent: Thursday, May 10, 2018 12:51:53 PM (UTC-05:00) Eastern Time (US & Can=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] ORO Show Tomorrow!
# body: tl;dr Olin Rock Orchestra is performing tomorrow, Friday the 11th, at 5pm i= n the Library Hey y'all! ORO is playing a short set in the upper level of the library tomorrow! Come and listen to some jammin' music, and send finals out with a bang. We're Oliners, we're an ensemble that could be called an orchestra, and we = might even play some Rock! (When we aren't playing jazz, movie scores or whatever genre Lucky Chops is= ) See you there! Event Link: http://events.olin.build/view/5af33baff199d40019cbe9ff
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfVictoria McDermott', 'Sent: Thursday, May 10, 2018 1:56:48 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] MitD Tomorrow', 'body: TLDR: signups for tomorrow here: https://docs.google.com/spreadsheets/d/1Lp= zHIh7d5BwaxNa4UQtNeTa-qbBdUc_9oAtJsSOcryc/edit?usp=3Ddrivesdk Hi all, We are having the last Murder in the dark game of the semester tomorrow and=  because we want as many people to be able to participate as possible we ar= e holding 3 sessions instead of the usual 2. If you would like to sign up f= or 2 sessions please put your name on the waitlist of the 2nd one you would=  like to do and we will let you know if there is space. Meet in WH3AL 15 mi= nutes before your section if you have not played before or would like a ref= resher on the rules. Let me know if you have any questions. Signups are her= e: https://docs.google.com/spreadsheets/d/1LpzHIh7d5BwaxNa4UQtNeTa-qbBdUc_9= oAtJsSOcryc/edit?usp=3Ddrivesdk. Vicky']
# From: CarpediemOn Behalf OfVictoria McDermott
# Sent: Thursday, May 10, 2018 1:56:48 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] MitD Tomorrow
# body: TLDR: signups for tomorrow here: https://docs.google.com/spreadsheets/d/1Lp= zHIh7d5BwaxNa4UQtNeTa-qbBdUc_9oAtJsSOcryc/edit?usp=3Ddrivesdk Hi all, We are having the last Murder in the dark game of the semester tomorrow and=  because we want as many people to be able to participate as possible we ar= e holding 3 sessions instead of the usual 2. If you would like to sign up f= or 2 sessions please put your name on the waitlist of the 2nd one you would=  like to do and we will let you know if there is space. Meet in WH3AL 15 mi= nutes before your section if you have not played before or would like a ref= resher on the rules. Let me know if you have any questions. Signups are her= e: https://docs.google.com/spreadsheets/d/1LpzHIh7d5BwaxNa4UQtNeTa-qbBdUc_9= oAtJsSOcryc/edit?usp=3Ddrivesdk. Vicky
# ['who', 'date', 'name', 'body']
# ['body: ']
# body:
# ['body']
# ['body: ']
# body:
# ['body']
# ['From: CarpediemOn Behalf OfShane Kelly', 'Sent: Thursday, May 10, 2018 2:58:00 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Free Discrete Textbook and Student Solutions Guide', 'body: Let me know if you want them and I can set them outside my suite. - Shane']
# From: CarpediemOn Behalf OfShane Kelly
# Sent: Thursday, May 10, 2018 2:58:00 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Free Discrete Textbook and Student Solutions Guide
# body: Let me know if you want them and I can set them outside my suite. - Shane
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfShane Kelly', 'Sent: Thursday, May 10, 2018 3:01:28 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Resolved: Free Discrete Textbook and Student Solutions=', 'body: On Thu, May 10, 2018 at 2:57 PM Shane Kelly <shane.kelly@students.olin.edu<= mailto:shane.kelly@students.olin.edu>> wrote: Let me know if you want them and I can set them outside my suite. - Shane']
# From: CarpediemOn Behalf OfShane Kelly
# Sent: Thursday, May 10, 2018 3:01:28 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Resolved: Free Discrete Textbook and Student Solutions=
# body: On Thu, May 10, 2018 at 2:57 PM Shane Kelly <shane.kelly@students.olin.edu<= mailto:shane.kelly@students.olin.edu>> wrote: Let me know if you want them and I can set them outside my suite. - Shane
# ['who', 'date', 'name', 'body']
# ['body: ']
# body:
# ['body']
# ['From: CarpediemOn Behalf OfSamuel Myers', 'Sent: Thursday, May 10, 2018 4:17:14 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: Carpe Diem', 'Subject: [Carpediem] Magic: the Gathering Draft!', "body: TL;DR: Sign up with your availability here<https://www.when2meet.com/?69015= 85-PATOc> to participate in a Magic draft sometime this week! We'll be draf= ting the newest set (Dominaria) and entry is free! Hey all, MtG Club has been dormant for a while but we'd like to get the ball rolling=  again, and the plan is to hold a draft before we all leave! We already hav= e packs so all you need to do is show up (no entry fee) and have a good tim= e (this is mandatory). Having drafted at least once before helps, but players of all skill levels = are welcome. Club membership has been somewhat variable and we've gotten a whole new cla= ss since the last time we did an event, so I'm gonna open this up to everyo= ne (or at least everyone on Carpe). Fill out this when2meet with your availability over the next few days, and = we'll have a draft with the first 8 people to sign up at an overlapping tim= e. https://www.when2meet.com/?6901585-PATOc Thanks all! Sam Grand Arbiter, Magic: the Gathering Club"]
# From: CarpediemOn Behalf OfSamuel Myers
# Sent: Thursday, May 10, 2018 4:17:14 PM (UTC-05:00) Eastern Time (US & Cana=
# To: Carpe Diem
# Subject: [Carpediem] Magic: the Gathering Draft!
# body: TL;DR: Sign up with your availability here<https://www.when2meet.com/?69015= 85-PATOc> to participate in a Magic draft sometime this week! We'll be draf= ting the newest set (Dominaria) and entry is free! Hey all, MtG Club has been dormant for a while but we'd like to get the ball rolling=  again, and the plan is to hold a draft before we all leave! We already hav= e packs so all you need to do is show up (no entry fee) and have a good tim= e (this is mandatory). Having drafted at least once before helps, but players of all skill levels = are welcome. Club membership has been somewhat variable and we've gotten a whole new cla= ss since the last time we did an event, so I'm gonna open this up to everyo= ne (or at least everyone on Carpe). Fill out this when2meet with your availability over the next few days, and = we'll have a draft with the first 8 people to sign up at an overlapping tim= e. https://www.when2meet.com/?6901585-PATOc Thanks all! Sam Grand Arbiter, Magic: the Gathering Club
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfNicholas Sherman', 'Sent: Thursday, May 10, 2018 4:30:28 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: Re: [Carpediem] SOLVED You has Discrete? I has cash.', 'body: From: Helpme <helpme-bounces@lists.olin.edu> On Behalf Of Nicholas Sherman Sent: Thursday, May 10, 2018 3:37 PM To: helpme@lists.olin.edu Subject: [Helpme] You has Discrete? I has cash. Hey! If you have a Discrete textbook you=92re looking at getting rid of, le= t me know and I=92ll buy it off of you! Thanks, =93Indiscrete=94 Nick']
# From: CarpediemOn Behalf OfNicholas Sherman
# Sent: Thursday, May 10, 2018 4:30:28 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: Re: [Carpediem] SOLVED You has Discrete? I has cash.
# body: From: Helpme <helpme-bounces@lists.olin.edu> On Behalf Of Nicholas Sherman Sent: Thursday, May 10, 2018 3:37 PM To: helpme@lists.olin.edu Subject: [Helpme] You has Discrete? I has cash. Hey! If you have a Discrete textbook you=92re looking at getting rid of, le= t me know and I=92ll buy it off of you! Thanks, =93Indiscrete=94 Nick
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfSean Foley', 'Sent: Thursday, May 10, 2018 5:25:20 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem (carpediem@lists.olin.edu)', 'Subject: [Carpediem] Coconut thai order', "body: I'm going to order some Coconut Thai in about 20 minutes; if you want in, l= et me know Get Outlook for Android<https://aka.ms/ghei36>"]
# From: CarpediemOn Behalf OfSean Foley
# Sent: Thursday, May 10, 2018 5:25:20 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem (carpediem@lists.olin.edu)
# Subject: [Carpediem] Coconut thai order
# body: I'm going to order some Coconut Thai in about 20 minutes; if you want in, l= et me know Get Outlook for Android<https://aka.ms/ghei36>
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfSean Foley', 'Sent: Thursday, May 10, 2018 6:12:02 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem (carpediem@lists.olin.edu)', 'Subject: [Carpediem] Resolved: Coconut thai order', 'body: Get Outlook for Android<https://aka.ms/ghei36> On Thu, May 10, 2018 at 5:25 PM -0400, "Sean Foley" <Sean.Foley@students.ol= in.edu<mailto:Sean.Foley@students.olin.edu>> wrote: I\'m going to order some Coconut Thai in about 20 minutes; if you want in, l= et me know Get Outlook for Android<https://aka.ms/ghei36>']
# From: CarpediemOn Behalf OfSean Foley
# Sent: Thursday, May 10, 2018 6:12:02 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem (carpediem@lists.olin.edu)
# Subject: [Carpediem] Resolved: Coconut thai order
# body: Get Outlook for Android<https://aka.ms/ghei36> On Thu, May 10, 2018 at 5:25 PM -0400, "Sean Foley" <Sean.Foley@students.ol= in.edu<mailto:Sean.Foley@students.olin.edu>> wrote: I'm going to order some Coconut Thai in about 20 minutes; if you want in, l= et me know Get Outlook for Android<https://aka.ms/ghei36>
# ['who', 'date', 'name', 'body']
# ['body: ']
# body:
# ['body']
# ['From: CarpediemOn Behalf OfSiddharth Garimella', 'Sent: Friday, May 11, 2018 12:42:24 AM (UTC-05:00) Eastern Time (US & Canad=', 'a)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Discrete for cash EOM', 'body: _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfSiddharth Garimella
# Sent: Friday, May 11, 2018 12:42:24 AM (UTC-05:00) Eastern Time (US & Canad=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Discrete for cash EOM
# body: _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfRowan Sharman', 'Sent: Friday, May 11, 2018 3:32:37 AM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Discrete for Nothing', 'body: I=92m not taking discrete, but if you give me your textbook, I will sell it=  to someone who has cash and give you nothing in return. -Rowan']
# From: CarpediemOn Behalf OfRowan Sharman
# Sent: Friday, May 11, 2018 3:32:37 AM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Discrete for Nothing
# body: I=92m not taking discrete, but if you give me your textbook, I will sell it=  to someone who has cash and give you nothing in return. -Rowan
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfMiriam Kome', 'Sent: Friday, May 11, 2018 8:57:15 AM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Selling backpacking pack! +the rest of my belongings t=', "body: I would like to sell my REI Flash 52 backpack (picture https://www.rei.com/= product/827065/rei-co-op-flash-52-pack-womens), would you like it? Make me an offer! Similar packs are 150 new, so offer less than that. Feel = free to ask questions or come try it on. While you're here, may I offer you the rest of my belongings:   *   2 luxurious memory foam fluff pillows   *   2 down throw pillows   *   nice plates and bowls and utensils and bamboo cutting boards and spic= es   *   A milk crate, a nice big basket, other storage solutions   *   toolbox and various tools, art supplies, school supplies   *   other assorted things Everything is pay what/if you want and most of it is outside my room EH219 = for your thrifty enjoyment. Tell your friends! Thanks! Mimi PS if you've read this far and you want bunny time, let me know and I may d= o another open house this weekend."]
# From: CarpediemOn Behalf OfMiriam Kome
# Sent: Friday, May 11, 2018 8:57:15 AM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Selling backpacking pack! +the rest of my belongings t=
# body: I would like to sell my REI Flash 52 backpack (picture https://www.rei.com/= product/827065/rei-co-op-flash-52-pack-womens), would you like it? Make me an offer! Similar packs are 150 new, so offer less than that. Feel = free to ask questions or come try it on. While you're here, may I offer you the rest of my belongings:      2 luxurious memory foam fluff pillows      2 down throw pillows      nice plates and bowls and utensils and bamboo cutting boards and spic= es      A milk crate, a nice big basket, other storage solutions      toolbox and various tools, art supplies, school supplies      other assorted things Everything is pay what/if you want and most of it is outside my room EH219 = for your thrifty enjoyment. Tell your friends! Thanks! Mimi PS if you've read this far and you want bunny time, let me know and I may d= o another open house this weekend.
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfKevin Crispie', 'Sent: Friday, May 11, 2018 10:45:29 AM (UTC-05:00) Eastern Time (US & Canad=', 'a)', 'To: carpediem@lists.olin.edu', 'Subject: Re: [Carpediem] Quality Suite/Dorm Room Tables for Sale', 'body: The tall table is spoken for, the short table (same footprint) is still up = for grabs. From: Kevin Crispie Sent: Monday, May 7, 2018 4:25 PM To: carpediem@lists.olin.edu Cc: Suraj Shroff <Suraj.Shroff@students.olin.edu>; Kevin Guo <Kevin.Guo@stu= dents.olin.edu> Subject: Quality Suite/Dorm Room Tables for Sale Hi everyone, Sunny, Kevin and I made some awesome tables for our suite this year and we= =92d love to pass them off to some other Oliners. They are both welded here=  at Olin and topped with plywood and some great stain and polyurethane fini= sh. We have one normal height table, and one standing/bar height table we a= re selling. Both come with pairs of integrated power outlets. Outlets! Imag= ine that! As your laptop grows old and decrepit like ours, you will always = have power close by if you own these tables. It=92s an opportunity you just=  can=92t pass up. We are taking offers for either one or both as a collection. Pricing is pre= tty negotiable, but the total material cost (not including time) was well o= ver $400. We probably spent a collective 80+ hours designing and making the= se. We=92d be willing to part with them for $300, but we=92ll take other of= fers. We can also throw in some purchased stools for the right offer as wel= l. Feel free to talk to us about it or come by EH3E to look at them and talk w= ith us. We have a few<https://i.imgur.com/UQJrk6y.png> pictures<https://img= ur.com/j13mdVI> as well<https://i.imgur.com/VQjQD4z.png> (LMK and I can sen= d you more pics). Thanks, and let us know if you=92re interested. Kevin']
# From: CarpediemOn Behalf OfKevin Crispie
# Sent: Friday, May 11, 2018 10:45:29 AM (UTC-05:00) Eastern Time (US & Canad=
# To: carpediem@lists.olin.edu
# Subject: Re: [Carpediem] Quality Suite/Dorm Room Tables for Sale
# body: The tall table is spoken for, the short table (same footprint) is still up = for grabs. From: Kevin Crispie Sent: Monday, May 7, 2018 4:25 PM To: carpediem@lists.olin.edu Cc: Suraj Shroff <Suraj.Shroff@students.olin.edu>; Kevin Guo <Kevin.Guo@stu= dents.olin.edu> Subject: Quality Suite/Dorm Room Tables for Sale Hi everyone, Sunny, Kevin and I made some awesome tables for our suite this year and we= =92d love to pass them off to some other Oliners. They are both welded here=  at Olin and topped with plywood and some great stain and polyurethane fini= sh. We have one normal height table, and one standing/bar height table we a= re selling. Both come with pairs of integrated power outlets. Outlets! Imag= ine that! As your laptop grows old and decrepit like ours, you will always = have power close by if you own these tables. It=92s an opportunity you just=  can=92t pass up. We are taking offers for either one or both as a collection. Pricing is pre= tty negotiable, but the total material cost (not including time) was well o= ver $400. We probably spent a collective 80+ hours designing and making the= se. We=92d be willing to part with them for $300, but we=92ll take other of= fers. We can also throw in some purchased stools for the right offer as wel= l. Feel free to talk to us about it or come by EH3E to look at them and talk w= ith us. We have a few<https://i.imgur.com/UQJrk6y.png> pictures<https://img= ur.com/j13mdVI> as well<https://i.imgur.com/VQjQD4z.png> (LMK and I can sen= d you more pics). Thanks, and let us know if you=92re interested. Kevin
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfEmily Lepert', 'Sent: Friday, May 11, 2018 10:53:33 AM (UTC-05:00) Eastern Time (US & Canad=', 'a)', 'To: carpediem@lists.olin.edu; helpme@lists.olin.edu', 'Subject: [Carpediem] Fly Olin', 'body: Here=92s a spreadsheet to figure out how to get to the airport next week: https://docs.google.com/spreadsheets/d/11hzuKcAYKsfMxnSWmatbb1GmgoVYBRNllnS= KAT94kgE']
# From: CarpediemOn Behalf OfEmily Lepert
# Sent: Friday, May 11, 2018 10:53:33 AM (UTC-05:00) Eastern Time (US & Canad=
# To: carpediem@lists.olin.edu; helpme@lists.olin.edu
# Subject: [Carpediem] Fly Olin
# body: Here=92s a spreadsheet to figure out how to get to the airport next week: https://docs.google.com/spreadsheets/d/11hzuKcAYKsfMxnSWmatbb1GmgoVYBRNllnS= KAT94kgE
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfShruti Iyer', 'Sent: Friday, May 11, 2018 11:43:50 AM (UTC-05:00) Eastern Time (US & Canad=', 'a)', 'To: carpediem@lists.olin.edu', 'Cc: Zhengyang Feng', 'body: Hi friends, Another semester is coming to an end. And our exchange students, Gwendal, H= ong Giap, Zhengyang, are saying good bye to us. Come to EH3 at 7:30 pm tonight to wish them good bye and good luck for thei= r future endeavors! There will be chips, hummus and drinks (bring cups). And some good music. -Shruti']
# From: CarpediemOn Behalf OfShruti Iyer
# Sent: Friday, May 11, 2018 11:43:50 AM (UTC-05:00) Eastern Time (US & Canad=
# To: carpediem@lists.olin.edu
# Cc: Zhengyang Feng
# body: Hi friends, Another semester is coming to an end. And our exchange students, Gwendal, H= ong Giap, Zhengyang, are saying good bye to us. Come to EH3 at 7:30 pm tonight to wish them good bye and good luck for thei= r future endeavors! There will be chips, hummus and drinks (bring cups). And some good music. -Shruti
# ['who', 'date', 'Cc', 'body']
# ['body: ']
# body:
# ['body']
# ['From: CarpediemOn Behalf OfJeremy Ryan', 'Sent: Friday, May 11, 2018 4:32:02 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists olin. edu', 'Subject: [Carpediem] ORO in 30 minutes! Library!', "body: We're Olin! We're sort of rock! And we're almost an orchestra!"]
# From: CarpediemOn Behalf OfJeremy Ryan
# Sent: Friday, May 11, 2018 4:32:02 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists olin. edu
# Subject: [Carpediem] ORO in 30 minutes! Library!
# body: We're Olin! We're sort of rock! And we're almost an orchestra!
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfChloe Grubb', 'Sent: Friday, May 11, 2018 5:11:54 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: Re: [Carpediem] ORO! Now! Library!', "body: They are awesome, as always. With ORO love, Chloe Sent from my iPhone On May 11, 2018, at 4:32 PM, Jeremy Ryan <jeremy.ryan@students.olin.edu<mai= lto:jeremy.ryan@students.olin.edu>> wrote: We're Olin! We're sort of rock! And we're almost an orchestra! _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu<mailto:Carpediem@lists.olin.edu> https://lists.olin.edu/mailman/listinfo/carpediem"]
# From: CarpediemOn Behalf OfChloe Grubb
# Sent: Friday, May 11, 2018 5:11:54 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: Re: [Carpediem] ORO! Now! Library!
# body: They are awesome, as always. With ORO love, Chloe Sent from my iPhone On May 11, 2018, at 4:32 PM, Jeremy Ryan <jeremy.ryan@students.olin.edu<mai= lto:jeremy.ryan@students.olin.edu>> wrote: We're Olin! We're sort of rock! And we're almost an orchestra! _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu<mailto:Carpediem@lists.olin.edu> https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfAnupama Krishnan', 'Sent: Friday, May 11, 2018 6:49:34 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Free food by the firepit!!', 'body: Come eat and talk to us about Student Government! -Ana']
# From: CarpediemOn Behalf OfAnupama Krishnan
# Sent: Friday, May 11, 2018 6:49:34 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Free food by the firepit!!
# body: Come eat and talk to us about Student Government! -Ana
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfShruti Iyer', 'Sent: Friday, May 11, 2018 7:20:32 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Cc: Zhengyang Feng', 'body: s! East Hall 3 Lounge. Bring cups for drinks. From: Carpediem <carpediem-bounces@lists.olin.edu> On Behalf Of Shruti Iyer Sent: Friday, May 11, 2018 11:44 AM To: carpediem@lists.olin.edu Cc: Zhengyang Feng <Zhengyang.Feng@students.olin.edu> Subject: [Carpediem] Farewell to our Exchange Students! Hi friends, Another semester is coming to an end. And our exchange students, Gwendal, H= ong Giap, Zhengyang, are saying good bye to us. Come to EH3 at 7:30 pm tonight to wish them good bye and good luck for thei= r future endeavors! There will be chips, hummus and drinks (bring cups). And some good music. -Shruti']
# From: CarpediemOn Behalf OfShruti Iyer
# Sent: Friday, May 11, 2018 7:20:32 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Cc: Zhengyang Feng
# body: s! East Hall 3 Lounge. Bring cups for drinks. From: Carpediem <carpediem-bounces@lists.olin.edu> On Behalf Of Shruti Iyer Sent: Friday, May 11, 2018 11:44 AM To: carpediem@lists.olin.edu Cc: Zhengyang Feng <Zhengyang.Feng@students.olin.edu> Subject: [Carpediem] Farewell to our Exchange Students! Hi friends, Another semester is coming to an end. And our exchange students, Gwendal, H= ong Giap, Zhengyang, are saying good bye to us. Come to EH3 at 7:30 pm tonight to wish them good bye and good luck for thei= r future endeavors! There will be chips, hummus and drinks (bring cups). And some good music. -Shruti
# ['who', 'date', 'Cc', 'body']
# ['From: CarpediemOn Behalf OfRebecca Jordan', 'Sent: Friday, May 11, 2018 8:28:20 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists. olin. edu', 'Subject: [Carpediem] Watch City Steampunk Festival', 'body: The Splendiferous Sixpenny Steampunk Society=92s traditional end-of-year ev= ent is the Watch City Steampunk Festival in Waltham. It takes place on May = 12, which is tomorrow. It=92s free to attend and wonderfully fun! You don=92t have to have done anything with the Steampunk Society previousl= y. Highlights include live music, swordfighting, vendors selling goggles and a= rmor, a parade, and seeing everyone=92s amazing costumes. Details and sched= ule are available here: https://www.watchcityfestival.com/ We will be meeting in EH1 at 9:30AM to get there when it starts, and probab= ly  having at least one car leaving by early afternoon. We have several dri= vers. If you arrange your own transportation, let me know you=92re coming s= o we can meet up! You don=92t need to have done anything with Steampunk Society to attend, an= d you don=92t need to wear a costume. Bring your friends! Prepare to be wal= king around all day. It=92s supposed to rain but the event is still on. Rebecca J']
# From: CarpediemOn Behalf OfRebecca Jordan
# Sent: Friday, May 11, 2018 8:28:20 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists. olin. edu
# Subject: [Carpediem] Watch City Steampunk Festival
# body: The Splendiferous Sixpenny Steampunk Society=92s traditional end-of-year ev= ent is the Watch City Steampunk Festival in Waltham. It takes place on May = 12, which is tomorrow. It=92s free to attend and wonderfully fun! You don=92t have to have done anything with the Steampunk Society previousl= y. Highlights include live music, swordfighting, vendors selling goggles and a= rmor, a parade, and seeing everyone=92s amazing costumes. Details and sched= ule are available here: https://www.watchcityfestival.com/ We will be meeting in EH1 at 9:30AM to get there when it starts, and probab= ly  having at least one car leaving by early afternoon. We have several dri= vers. If you arrange your own transportation, let me know you=92re coming s= o we can meet up! You don=92t need to have done anything with Steampunk Society to attend, an= d you don=92t need to wear a costume. Bring your friends! Prepare to be wal= king around all day. It=92s supposed to rain but the event is still on. Rebecca J
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfTaylor Sheneman', 'Sent: Friday, May 11, 2018 9:00:36 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: Carpe Diem', 'Subject: [Carpediem] Fireside, the reckoning', 'body: Are you excited finals are over?! Are you just kind of tired and dead? Yeah same though Well come by anyway and hang out To celebrate this final opening I=92m doing nothing differently 10ish to 1ish -Taylor localhost:fireside (Also I=92m still working off a crap piece of plywood cause I can=92t multi= task finals and wood finishing. Who coulda guessed)']
# From: CarpediemOn Behalf OfTaylor Sheneman
# Sent: Friday, May 11, 2018 9:00:36 PM (UTC-05:00) Eastern Time (US & Canada=
# To: Carpe Diem
# Subject: [Carpediem] Fireside, the reckoning
# body: Are you excited finals are over?! Are you just kind of tired and dead? Yeah same though Well come by anyway and hang out To celebrate this final opening I=92m doing nothing differently 10ish to 1ish -Taylor localhost:fireside (Also I=92m still working off a crap piece of plywood cause I can=92t multi= task finals and wood finishing. Who coulda guessed)
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfShawn Albertson', 'Sent: Saturday, May 12, 2018 1:21:48 AM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] dance floor in the library NOW EOM', 'body: <3 _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfShawn Albertson
# Sent: Saturday, May 12, 2018 1:21:48 AM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] dance floor in the library NOW EOM
# body: <3 _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfWilliam Manidis', 'Sent: Saturday, May 12, 2018 1:22:29 AM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: Shawn Albertson', 'Cc: carpediem@lists.olin.edu', 'body: Leon DJ-ing > On May 12, 2018, at 1:21 AM, Shawn Albertson <shawn.albertson@students.ol= in.edu> wrote: > > <3 > _______________________________________________ > Carpediem mailing list > Carpediem@lists.olin.edu > https://lists.olin.edu/mailman/listinfo/carpediem _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfWilliam Manidis
# Sent: Saturday, May 12, 2018 1:22:29 AM (UTC-05:00) Eastern Time (US & Cana=
# To: Shawn Albertson
# Cc: carpediem@lists.olin.edu
# body: Leon DJ-ing > On May 12, 2018, at 1:21 AM, Shawn Albertson <shawn.albertson@students.ol= in.edu> wrote: > > <3 > _______________________________________________ > Carpediem mailing list > Carpediem@lists.olin.edu > https://lists.olin.edu/mailman/listinfo/carpediem _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'Cc', 'body']
# ['body: ']
# body:
# ['body']
# ['From: CarpediemOn Behalf OfBrennan VandenHoek', 'Sent: Saturday, May 12, 2018 1:16:35 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Chacos for sale - $20', 'body: I have some men=92s size 11 black chacos that I don=92t need. Let me know i= f you want them. Looking to get $20 Brennan']
# From: CarpediemOn Behalf OfBrennan VandenHoek
# Sent: Saturday, May 12, 2018 1:16:35 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Chacos for sale - $20
# body: I have some men=92s size 11 black chacos that I don=92t need. Let me know i= f you want them. Looking to get $20 Brennan
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfJeremy Ryan', 'Sent: Saturday, May 12, 2018 1:39:09 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Three second videos', 'body: Compiling several as an entry to the 30-second video. Send your three-secon= d clips to me. Jeremy']
# From: CarpediemOn Behalf OfJeremy Ryan
# Sent: Saturday, May 12, 2018 1:39:09 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Three second videos
# body: Compiling several as an entry to the 30-second video. Send your three-secon= d clips to me. Jeremy
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfErika Serna', 'Sent: Saturday, May 12, 2018 2:52:50 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Cc: open@lists.olin.edu', "body: Good evening, I have chips and nacho cheese because I miss home but also because snacks. = (chips) At 6pm today, in the WH or maybe EH kitchen, depending on availability, and=  surrounding lounges, join me for chips and nacho cheese sauce. There's availability for Flaming Hots, Takis, Doritos, Corn chips, and mayb= e other??? with cheese sauce. There may also be jalapenos. Please bring your own bowls, or if someone has paper bowls or plates I can = buy off them, Id appreciate it. Information talked about would be what do the flags mean, what is it like being gay at college (/Olin specifically), how do you support your friends who are gay as a straight person, what about gender, impact of pronouns, intersectionality of LGBT+ groups and race, what's with the labels, what about queer? the controversy. also I would like feedback about what you would like from OPEN! Thanks, Serna If you'd like to help DM me. especially about plates and spoons. If you have questions u can also dm me! _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem"]
# From: CarpediemOn Behalf OfErika Serna
# Sent: Saturday, May 12, 2018 2:52:50 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Cc: open@lists.olin.edu
# body: Good evening, I have chips and nacho cheese because I miss home but also because snacks. = (chips) At 6pm today, in the WH or maybe EH kitchen, depending on availability, and=  surrounding lounges, join me for chips and nacho cheese sauce. There's availability for Flaming Hots, Takis, Doritos, Corn chips, and mayb= e other??? with cheese sauce. There may also be jalapenos. Please bring your own bowls, or if someone has paper bowls or plates I can = buy off them, Id appreciate it. Information talked about would be what do the flags mean, what is it like being gay at college (/Olin specifically), how do you support your friends who are gay as a straight person, what about gender, impact of pronouns, intersectionality of LGBT+ groups and race, what's with the labels, what about queer? the controversy. also I would like feedback about what you would like from OPEN! Thanks, Serna If you'd like to help DM me. especially about plates and spoons. If you have questions u can also dm me! _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'Cc', 'body']
# ['From: CarpediemOn Behalf OfBrennan VandenHoek', 'Sent: Saturday, May 12, 2018 3:33:00 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Brand new vans for sale - $20', 'body: I have navy blue vans that I have litterally worn once. They are size 11. L= et me know if you want them! Brennan']
# From: CarpediemOn Behalf OfBrennan VandenHoek
# Sent: Saturday, May 12, 2018 3:33:00 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Brand new vans for sale - $20
# body: I have navy blue vans that I have litterally worn once. They are size 11. L= et me know if you want them! Brennan
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfMiranda McMillen', 'Sent: Saturday, May 12, 2018 3:36:23 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Blue Bins Wanted:', 'body: I need ONE More blue bin. If you have an xtra one you are willing to sell m= e lemme know']
# From: CarpediemOn Behalf OfMiranda McMillen
# Sent: Saturday, May 12, 2018 3:36:23 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Blue Bins Wanted:
# body: I need ONE More blue bin. If you have an xtra one you are willing to sell m= e lemme know
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfMelissa Anthony', 'Sent: Saturday, May 12, 2018 3:48:35 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Giant Hard Wood ;)', 'body: [image1.jpeg] [image2.jpeg][image3.png] Nice and green. I tried to pick it up but it=92s too heavy for me. I=92ll drive you if you let me have some. Melissa']
# From: CarpediemOn Behalf OfMelissa Anthony
# Sent: Saturday, May 12, 2018 3:48:35 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Giant Hard Wood ;)
# body: [image1.jpeg] [image2.jpeg][image3.png] Nice and green. I tried to pick it up but it=92s too heavy for me. I=92ll drive you if you let me have some. Melissa
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfShawn Albertson', 'Sent: Saturday, May 12, 2018 3:53:32 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: Brennan VandenHoek', 'Cc: carpediem@lists.olin.edu', 'body: Brennan is selling his van for $20 On May 12, 2018, at 3:33 PM, Brennan VandenHoek <Brennan.VandenHoek@student= s.olin.edu<mailto:Brennan.VandenHoek@students.olin.edu>> wrote: I have navy blue vans that I have litterally worn once. They are size 11. L= et me know if you want them! Brennan']
# From: CarpediemOn Behalf OfShawn Albertson
# Sent: Saturday, May 12, 2018 3:53:32 PM (UTC-05:00) Eastern Time (US & Cana=
# To: Brennan VandenHoek
# Cc: carpediem@lists.olin.edu
# body: Brennan is selling his van for $20 On May 12, 2018, at 3:33 PM, Brennan VandenHoek <Brennan.VandenHoek@student= s.olin.edu<mailto:Brennan.VandenHoek@students.olin.edu>> wrote: I have navy blue vans that I have litterally worn once. They are size 11. L= et me know if you want them! Brennan
# ['who', 'date', 'Cc', 'body']
# ['From: CarpediemOn Behalf OfGabrielle Clarke', 'Sent: Saturday, May 12, 2018 3:54:02 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Selling Tempur-Pedic', 'body: I=92m selling my Tempur-Pedic memory foam mattress topper, size twin/twin X= L. It=92s suuuuper comfortable, on the firm side, and it has served me well= . It was under a mattress cover the whole time, so it=92s still in really g= ood condition. Retails for $300, https://www.tempurpedic.com/other-products/tempur-topper-= supreme/v/286/. It can be yours for $60, or make me an offer. Gaby']
# From: CarpediemOn Behalf OfGabrielle Clarke
# Sent: Saturday, May 12, 2018 3:54:02 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Selling Tempur-Pedic
# body: I=92m selling my Tempur-Pedic memory foam mattress topper, size twin/twin X= L. It=92s suuuuper comfortable, on the firm side, and it has served me well= . It was under a mattress cover the whole time, so it=92s still in really g= ood condition. Retails for $300, https://www.tempurpedic.com/other-products/tempur-topper-= supreme/v/286/. It can be yours for $60, or make me an offer. Gaby
# ['who', 'date', 'name', 'body']
# ['body: ']
# body:
# ['body']
# ['From: CarpediemOn Behalf OfXiaozheng Xu', 'Sent: Saturday, May 12, 2018 5:52:12 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Selling 2 blue bins. Price negotiable', 'body: They are actually black, but better than most blue bins. Bought from the co= ntainer store. _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfXiaozheng Xu
# Sent: Saturday, May 12, 2018 5:52:12 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Selling 2 blue bins. Price negotiable
# body: They are actually black, but better than most blue bins. Bought from the co= ntainer store. _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfErika Serna', 'Sent: Saturday, May 12, 2018 6:01:52 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Cc: open@lists.olin.edu', 'body: Hey! Event now! EOM Thanks! Serna _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfErika Serna
# Sent: Saturday, May 12, 2018 6:01:52 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Cc: open@lists.olin.edu
# body: Hey! Event now! EOM Thanks! Serna _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'Cc', 'body']
# ['From: CarpediemOn Behalf OfXiaozheng Xu', 'Sent: Saturday, May 12, 2018 7:23:42 PM (UTC-05:00) Eastern Time (US & Cana=', 'da)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] RESOLVED. Selling 2 blue bins. Price negotiable', 'body: Begin forwarded message: From: Xiaozheng Xu <Xiaozheng.Xu@students.olin.edu<mailto:Xiaozheng.Xu@stud= ents.olin.edu>> Subject: [Carpediem] Selling 2 blue bins. Price negotiable Date: May 12, 2018 at 5:52:12 PM EDT To: "carpediem@lists.olin.edu<mailto:carpediem@lists.olin.edu>" <carpediem@= lists.olin.edu<mailto:carpediem@lists.olin.edu>> They are actually black, but better than most blue bins. Bought from the co= ntainer store. _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu<mailto:Carpediem@lists.olin.edu> https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfXiaozheng Xu
# Sent: Saturday, May 12, 2018 7:23:42 PM (UTC-05:00) Eastern Time (US & Cana=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] RESOLVED. Selling 2 blue bins. Price negotiable
# body: Begin forwarded message: From: Xiaozheng Xu <Xiaozheng.Xu@students.olin.edu<mailto:Xiaozheng.Xu@stud= ents.olin.edu>> Subject: [Carpediem] Selling 2 blue bins. Price negotiable Date: May 12, 2018 at 5:52:12 PM EDT To: "carpediem@lists.olin.edu<mailto:carpediem@lists.olin.edu>" <carpediem@= lists.olin.edu<mailto:carpediem@lists.olin.edu>> They are actually black, but better than most blue bins. Bought from the co= ntainer store. _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu<mailto:Carpediem@lists.olin.edu> https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfMark Goldwater', 'Sent: Saturday, May 12, 2018 10:08:26 PM (UTC-05:00) Eastern Time (US & Can=', 'ada)', 'To: Carpe Diem', 'Subject: [Carpediem] Harry Potter Marathon in WH2! EOM', 'body: ']
# From: CarpediemOn Behalf OfMark Goldwater
# Sent: Saturday, May 12, 2018 10:08:26 PM (UTC-05:00) Eastern Time (US & Can=
# To: Carpe Diem
# Subject: [Carpediem] Harry Potter Marathon in WH2! EOM
# body:
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfRobert Siegel', 'Sent: Saturday, May 12, 2018 10:53:37 PM (UTC-05:00) Eastern Time (US & Can=', 'ada)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] EH 2N EOM', 'body: ']
# From: CarpediemOn Behalf OfRobert Siegel
# Sent: Saturday, May 12, 2018 10:53:37 PM (UTC-05:00) Eastern Time (US & Can=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] EH 2N EOM
# body:
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfAndrew Deaver', 'Sent: Saturday, May 12, 2018 11:37:29 PM (UTC-05:00) Eastern Time (US & Can=', 'ada)', 'To: carpediem@lists.olin.edu', "Subject: [Carpediem] Thank Katie Hite for Ordering Domino's for Us. She's a=", 'body: Katie is receiving rave reviews like: "You\'re so responsible" - TIME Magazine (probably) "I love Katie so much" - The New York Times "Someone spilled drink on this pretzel" - Robbie Now EOM.']
# From: CarpediemOn Behalf OfAndrew Deaver
# Sent: Saturday, May 12, 2018 11:37:29 PM (UTC-05:00) Eastern Time (US & Can=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Thank Katie Hite for Ordering Domino's for Us. She's a=
# body: Katie is receiving rave reviews like: "You're so responsible" - TIME Magazine (probably) "I love Katie so much" - The New York Times "Someone spilled drink on this pretzel" - Robbie Now EOM.
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfKai Levy', 'Sent: Saturday, May 12, 2018 11:50:18 PM (UTC-05:00) Eastern Time (US & Can=', 'ada)', 'To: Robert Siegel', 'Cc: carpediem@lists.olin.edu', 'body: rip On Sat, May 12, 2018, 22:53 Robert Siegel <Robert.Siegel@students.olin.edu<= mailto:Robert.Siegel@students.olin.edu>> wrote: _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu<mailto:Carpediem@lists.olin.edu> https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfKai Levy
# Sent: Saturday, May 12, 2018 11:50:18 PM (UTC-05:00) Eastern Time (US & Can=
# To: Robert Siegel
# Cc: carpediem@lists.olin.edu
# body: rip On Sat, May 12, 2018, 22:53 Robert Siegel <Robert.Siegel@students.olin.edu<= mailto:Robert.Siegel@students.olin.edu>> wrote: _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu<mailto:Carpediem@lists.olin.edu> https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'Cc', 'body']
# ['From: CarpediemOn Behalf OfMaxmilian Wei', 'Sent: Sunday, May 13, 2018 11:18:54 AM (UTC-05:00) Eastern Time (US & Canad=', 'a)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] volunteers to get dunked on', 'body: You know how its summer and that means going to the beach, or something lik= e that?  We have the next best thing.  Do you want to drop 3 feet into refr= eshingly cold water on this nice 55 fahrenheit degree day?  If that sounds = like your ideal way to spend Sunday Afternoon, sign up for a shift on the d= unk tank! link here: https://docs.google.com/spreadsheets/d/16qhRw8VamRoqKYix7jTdBigD= vvhPDrYFiKYFVgQpdeg/edit?usp=3Dsharing -max wei Get Outlook for iOS<https://aka.ms/o0ukef>']
# From: CarpediemOn Behalf OfMaxmilian Wei
# Sent: Sunday, May 13, 2018 11:18:54 AM (UTC-05:00) Eastern Time (US & Canad=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] volunteers to get dunked on
# ...
# From: CarpediemOn Behalf OfLakhvinder Jordan
# Sent: Sunday, May 13, 2018 12:49:46 PM (UTC-05:00) Eastern Time (US & Canad=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Make me soaking wet
# body: I=92ll be in the dunk tank soon _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfXiaozheng Xu', 'Sent: Sunday, May 13, 2018 12:56:29 PM (UTC-05:00) Eastern Time (US & Canad=', 'a)', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Free Discrete textbook outside EH3NW and other things', 'body: Including: - Discrete text book - cute animals - Clear Care contact lens wash liquid - poker cards - swag from Google - MDF boards for laser cutting Clothing:  - Cute semi casual dress from Ross - American Eagle size 2 jeans in great condition - cardigan from Urban outfitter I also have a monitor for sale ($50) https://www.amazon.com/Acer-G226HQL-21= -5-Inch-Screen-Monitor/dp/B009POS0GS/ref=3Dsr_1_2?s=3Dpc&ie=3DUTF8&qid=3D15= 26230320&sr=3D1-2&keywords=3Dacer+monitor And a vacuum cleaner ($10) really cute red one that haven=92t been used muc= h And a Ikea white clock ($7) Let me know if you=92re interested in any and take free stuff~ Thanks, Judy']
# From: CarpediemOn Behalf OfXiaozheng Xu
# Sent: Sunday, May 13, 2018 12:56:29 PM (UTC-05:00) Eastern Time (US & Canad=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Free Discrete textbook outside EH3NW and other things
# body: Including: - Discrete text book - cute animals - Clear Care contact lens wash liquid - poker cards - swag from Google - MDF boards for laser cutting Clothing:  - Cute semi casual dress from Ross - American Eagle size 2 jeans in great condition - cardigan from Urban outfitter I also have a monitor for sale ($50) https://www.amazon.com/Acer-G226HQL-21= -5-Inch-Screen-Monitor/dp/B009POS0GS/ref=3Dsr_1_2?s=3Dpc&ie=3DUTF8&qid=3D15= 26230320&sr=3D1-2&keywords=3Dacer+monitor And a vacuum cleaner ($10) really cute red one that haven=92t been used muc= h And a Ikea white clock ($7) Let me know if you=92re interested in any and take free stuff~ Thanks, Judy
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfEmily Kohler', 'Sent: Sunday, May 13, 2018 1:17:18 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Table for the summer', 'body: Are you around for the summer and want a table? It=92s a bar height table (= with stools if you want them). -Emily']
# From: CarpediemOn Behalf OfEmily Kohler
# Sent: Sunday, May 13, 2018 1:17:18 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Table for the summer
# body: Are you around for the summer and want a table? It=92s a bar height table (= with stools if you want them). -Emily
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfSophia Nielsen', 'Sent: Sunday, May 13, 2018 7:38:19 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: Re: [Carpediem] Stuff to borrow, Stuff to buy', "body: Come pick up stuff from 4pm to 6pm. I price dropped a bunch of the for-keep= s items so check that out. On Tue, May 8, 2018 at 2:02 AM Sophia R Nielsen <sophia.nielsen@students.ol= in.edu<mailto:sophia.nielsen@students.olin.edu>> wrote: tldr; want stuff? Go here<https://docs.google.com/spreadsheets/d/1GQR6wXtaq= IG13PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing>. I'll be away during the summer and studying abroad in the fall. I'm trying = to get babysitters for some of my stuff/get rid of some of it all together.=  If you have stuff you want to lend out or sell, feel free to add it to the=  spreadsheet, just add yourself as the owner so people know who to contact.=  (There's one tab for stuff I'm getting rid of for good and one for stuff I= 'm gonna want back). Stuff includes: shelving, vacuums, textbooks, a DVD player you should take,=  and so much more! Here's the link again: https://docs.google.com/spreadsheets/d/1GQR6wXtaqIG1= 3PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing Please take some stuff, Sophia"]
# From: CarpediemOn Behalf OfSophia Nielsen
# Sent: Sunday, May 13, 2018 7:38:19 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: Re: [Carpediem] Stuff to borrow, Stuff to buy
# body: Come pick up stuff from 4pm to 6pm. I price dropped a bunch of the for-keep= s items so check that out. On Tue, May 8, 2018 at 2:02 AM Sophia R Nielsen <sophia.nielsen@students.ol= in.edu<mailto:sophia.nielsen@students.olin.edu>> wrote: tldr; want stuff? Go here<https://docs.google.com/spreadsheets/d/1GQR6wXtaq= IG13PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing>. I'll be away during the summer and studying abroad in the fall. I'm trying = to get babysitters for some of my stuff/get rid of some of it all together.=  If you have stuff you want to lend out or sell, feel free to add it to the=  spreadsheet, just add yourself as the owner so people know who to contact.=  (There's one tab for stuff I'm getting rid of for good and one for stuff I= 'm gonna want back). Stuff includes: shelving, vacuums, textbooks, a DVD player you should take,=  and so much more! Here's the link again: https://docs.google.com/spreadsheets/d/1GQR6wXtaqIG1= 3PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing Please take some stuff, Sophia
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfGabrielle Clarke', 'Sent: Sunday, May 13, 2018 5:03:10 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: [Carpediem] Strathmore watercolor paper', 'body: I have two mostly full pads of Strathmore Series 300 watercolor paper, 9=94= x12=94 and 11=94x15=94. They=92re outside my suite, EH2E. Venmo me a couple bucks if you take them. G _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem']
# From: CarpediemOn Behalf OfGabrielle Clarke
# Sent: Sunday, May 13, 2018 5:03:10 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: [Carpediem] Strathmore watercolor paper
# body: I have two mostly full pads of Strathmore Series 300 watercolor paper, 9=94= x12=94 and 11=94x15=94. They=92re outside my suite, EH2E. Venmo me a couple bucks if you take them. G _______________________________________________ Carpediem mailing list Carpediem@lists.olin.edu https://lists.olin.edu/mailman/listinfo/carpediem
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfSophia Nielsen', 'Sent: Sunday, May 13, 2018 5:03:22 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu', 'Subject: Re: [Carpediem] Stuff to borrow, Stuff to buy', "body: Room #403 On Tue, May 8, 2018 at 02:02 Sophia R Nielsen <sophia.nielsen@students.olin= .edu<mailto:sophia.nielsen@students.olin.edu>> wrote: tldr; want stuff? Go here<https://docs.google.com/spreadsheets/d/1GQR6wXtaq= IG13PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing>. I'll be away during the summer and studying abroad in the fall. I'm trying = to get babysitters for some of my stuff/get rid of some of it all together.=  If you have stuff you want to lend out or sell, feel free to add it to the=  spreadsheet, just add yourself as the owner so people know who to contact.=  (There's one tab for stuff I'm getting rid of for good and one for stuff I= 'm gonna want back). Stuff includes: shelving, vacuums, textbooks, a DVD player you should take,=  and so much more! Here's the link again: https://docs.google.com/spreadsheets/d/1GQR6wXtaqIG1= 3PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing Please take some stuff, Sophia"]
# From: CarpediemOn Behalf OfSophia Nielsen
# Sent: Sunday, May 13, 2018 5:03:22 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu
# Subject: Re: [Carpediem] Stuff to borrow, Stuff to buy
# body: Room #403 On Tue, May 8, 2018 at 02:02 Sophia R Nielsen <sophia.nielsen@students.olin= .edu<mailto:sophia.nielsen@students.olin.edu>> wrote: tldr; want stuff? Go here<https://docs.google.com/spreadsheets/d/1GQR6wXtaq= IG13PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing>. I'll be away during the summer and studying abroad in the fall. I'm trying = to get babysitters for some of my stuff/get rid of some of it all together.=  If you have stuff you want to lend out or sell, feel free to add it to the=  spreadsheet, just add yourself as the owner so people know who to contact.=  (There's one tab for stuff I'm getting rid of for good and one for stuff I= 'm gonna want back). Stuff includes: shelving, vacuums, textbooks, a DVD player you should take,=  and so much more! Here's the link again: https://docs.google.com/spreadsheets/d/1GQR6wXtaqIG1= 3PZ54pE8au7m3YB5bkJoL6y3Y1iNPrA/edit?usp=3Dsharing Please take some stuff, Sophia
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfEmily Lepert', 'Sent: Sunday, May 13, 2018 5:09:53 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem@lists.olin.edu; helpme@lists.olin.edu', 'Subject: Re: [Carpediem] Fly Olin', "body: Bumping this so it's at the top of the mailing lists. To clarify for first years, there is no BOW shuttle organized to shuttle pe= ople to the airport. This spreadsheet is for people to figure how to get th= ere on their own. On Fri, May 11, 2018 at 10:53 AM Emily Lepert <emily.lepert@students.olin.e= du<mailto:emily.lepert@students.olin.edu>> wrote: Here=92s a spreadsheet to figure out how to get to the airport next week: https://docs.google.com/spreadsheets/d/11hzuKcAYKsfMxnSWmatbb1GmgoVYBRNllnS= KAT94kgE"]
# From: CarpediemOn Behalf OfEmily Lepert
# Sent: Sunday, May 13, 2018 5:09:53 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem@lists.olin.edu; helpme@lists.olin.edu
# Subject: Re: [Carpediem] Fly Olin
# body: Bumping this so it's at the top of the mailing lists. To clarify for first years, there is no BOW shuttle organized to shuttle pe= ople to the airport. This spreadsheet is for people to figure how to get th= ere on their own. On Fri, May 11, 2018 at 10:53 AM Emily Lepert <emily.lepert@students.olin.e= du<mailto:emily.lepert@students.olin.edu>> wrote: Here=92s a spreadsheet to figure out how to get to the airport next week: https://docs.google.com/spreadsheets/d/11hzuKcAYKsfMxnSWmatbb1GmgoVYBRNllnS= KAT94kgE
# ['who', 'date', 'name', 'body']
# ['From: CarpediemOn Behalf OfAaron Greiner (Forwarding)', 'Sent: Sunday, May 13, 2018 5:30:31 PM (UTC-05:00) Eastern Time (US & Canada=', ')', 'To: carpediem (carpediem@lists.olin.edu)', 'Subject: [Carpediem] Have my bar next year (and/or this summer)', 'body: I have a suite bar in my sweet that I am looking to lend to a caring owner = next year (or over the summer if you are interested). It is a beautiful bar=  made from barn wood by my brother and father. (see attached photo) I am looking to lend it to someone for the next year, but will most likely = want it back after then. If you are interested in having it for the summer = or next year, let me know. -Aaron [cid:0D9EC62D-0945-49D0-9C3A-F11BE98FD7C6@olin.edu]']
# From: CarpediemOn Behalf OfAaron Greiner (Forwarding)
# Sent: Sunday, May 13, 2018 5:30:31 PM (UTC-05:00) Eastern Time (US & Canada=
# To: carpediem (carpediem@lists.olin.edu)
# Subject: [Carpediem] Have my bar next year (and/or this summer)
# body: I have a suite bar in my sweet that I am looking to lend to a caring owner = next year (or over the summer if you are interested). It is a beautiful bar=  made from barn wood by my brother and father. (see attached photo) I am looking to lend it to someone for the next year, but will most likely = want it back after then. If you are interested in having it for the summer = or next year, let me know. -Aaron [cid:0D9EC62D-0945-49D0-9C3A-F11BE98FD7C6@olin.edu]
# ['who', 'date', 'name', 'body']
# [{'who': 'Grace Montagnino', 'date': 'Thursday, May 10, 2018 12:48:36 PM', 'name': '[Carpediem] Donate to the Needham Community Council', 'body': "From: CarpeSERV [mailto:carpeserv-bounces@lists.olin.edu] On Behalf Of Just= in Kunimune (Forwarding) Sent: Wednesday, May 9, 2018 9:41 PM To: carpediem@lists olin. edu <carpediem@lists.olin.edu>; carpeserv@lists.o= lin.edu Subject: [CarpeSERV] More boxes for the Needham Community Council tl;dr =96 put any excess food and cleaning items in the labelled bins in th= e residence halls to donate them to a food bank. Long version: If you saw Melissa's email, it's the same thing, but now with more boxes th= at will be there for longer! There is now a labelled box in the WH anteloun= ge, and will be one in EH tomorrow, for donating food and toiletries to the=  Needham Community Council Food Pantry. These boxes will be out through the=  end of the semester, so feel free to wait until the last moment to put thi= ngs in. A full list of what kinds of things for which the NCC is looking ca= n be found here<http://needhamcommunitycouncil.org/wp-content/uploads/2018/= 05/FP-Wishlist-May-2018.pdf>. Thank you, Justin Director of SERV"}, {'who': 'Jared Briskman', 'date': 'Thursday, May 10, 2018 12:51:53 PM', 'name': '[Carpediem] ORO Show Tomorrow!', 'body': "tl;dr Olin Rock Orchestra is performing tomorrow, Friday the 11th, at 5pm i= n the Library Hey y'all! ORO is playing a short set in the upper level of the library tomorrow! Come and listen to some jammin' music, and send finals out with a bang. We're Oliners, we're an ensemble that could be called an orchestra, and we = might even play some Rock! (When we aren't playing jazz, movie scores or whatever genre Lucky Chops is= ) See you there! Event Link: http://events.olin.build/view/5af33baff199d40019cbe9ff"}, {'who': 'Victoria McDermott', 'date': 'Thursday, May 10, 2018 1:56:48 PM', 'name': '[Carpediem] MitD Tomorrow', 'body': 'TLDR: signups for tomorrow here: https://docs.google.com/spreadsheets/d/1Lp= zHIh7d5BwaxNa4UQtNeTa-qbBdUc_9oAtJsSOcryc/edit?usp=3Ddrivesdk Hi all, We are having the last Murder in the dark game of the semester tomorrow and=  because we want as many people to be able to participate as possible we ar= e holding 3 sessions instead of the usual 2. If you would like to sign up f= or 2 sessions please put your name on the waitlist of the 2nd one you would=  like to do and we will let you know if there is space. Meet in WH3AL 15 mi= nutes before your section if you have not played before or would like a ref= resher on the rules. Let me know if you have any questions. Signups are her= e: https://docs.google.com/spreadsheets/d/1LpzHIh7d5BwaxNa4UQtNeTa-qbBdUc_9= oAtJsSOcryc/edit?usp=3Ddrivesdk. Vicky'}, {'body': ''}, {'body': ''}, {'who': 'Shane Kelly', 'date': 'Thursday, May 10, 2018 2:58:00 PM', 'name': '[Carpediem] Free Discrete Textbook and Student Solutions Guide', 'body': 'Let me know if you want them and I can set them outside my suite. - Shane'}, {'who': 'Shane Kelly', 'date': 'Thursday, May 10, 2018 3:01:28 PM', 'name': '[Carpediem] Resolved: Free Discrete Textbook and Student Solutions=', 'body': 'On Thu, May 10, 2018 at 2:57 PM Shane Kelly <shane.kelly@students.olin.edu<= mailto:shane.kelly@students.olin.edu>> wrote: Let me know if you want them and I can set them outside my suite. - Shane'}, {'body': ''}, {'who': 'Samuel Myers', 'date': 'Thursday, May 10, 2018 4:17:14 PM', 'name': '[Carpediem] Magic: the Gathering Draft!', 'body': "TL;DR: Sign up with your availability here<https://www.when2meet.com/?69015= 85-PATOc> to participate in a Magic draft sometime this week! We'll be draf= ting the newest set (Dominaria) and entry is free! Hey all, MtG Club has been dormant for a while but we'd like to get the ball rolling=  again, and the plan is to hold a draft before we all leave! We already hav= e packs so all you need to do is show up (no entry fee) and have a good tim= e (this is mandatory). Having drafted at least once be ...

# %% [markdown]
# We will classify the data according to tags represented by numbers with the following schema:
# 0 - academic
# 1 - burstthebubble
# 2 - food
# 3 - holidays
# 4 - StAR
# 5 - admission
# 6 - athletics
# 7 - BOW
# 8 - collaboratory
# 9 - CORe
# 10 - diversity
# 11 - Final Events
# 12 - FWOP
# 13 - GrOW
# 14 - hours
# 15 - library
# 16 - NINJAs
# 17 - OFAC
# 18 - parties
# 19 - performance
# 20 - PGP
# 21 - robolab
# 22 - shop
# 23 - SLAC
# 24 - talks
# 25 - transportation
# 26 - stuff
# 27 - housing
# 28 - other
# ** Note that we have added 3 categories to represent emails that indicate something is free or for sale (26), housing (27), and other (28). These are probably events that wouldn't make it onto the actual page but are still useful to classify to figure out that they shouldn't become events.
